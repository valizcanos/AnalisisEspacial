# %% [markdown]
# # Taller 4

# %% [markdown]
# A partir de los siguientes conjunto de datos tomados del <a href="https://cds.climate.copernicus.eu/cdsapp#!/search?type=dataset">CDS</a>:<br>
# * Ozone monthly gridded data from 1970 to present derived from satellite observations (ej. O3)
# * Carbon dioxide data from 2002 to present derived from satellite observations (ej. CO2)
# * Climate suitability indicators for tourism from 1970 to 2100 over Europe derived from climate projections (ej. turismo)
# * Climatic suitability for the presence and seasonal activity of the Aedes albopictus mosquito for Europe derived from climate projections (ej. mosquitos)
# * Soil erosion indicators for Italy from 1981 to 2080 (ej.erosión)
# * Crop productivity and evapotranspiration indicators from 2000 to present derived from satellite observations (ej. maíz)
# * Heat waves and cold spells in Europe derived from climate projections (ej. calor)
# * Surface radiation budget from 1982 to present derived from satellite observations (ej. radiacion)
# * Fire burned area from 2001 to present derived from satellite observations (ej. quema)
#
# Van realizar las respectivas medidas de tendencia central, su análisis exploratorio de datos y su autocorrelación espacial, respecto a una variable que sea de su interés.

# %% [markdown]
# A continuación se describen los procedimientos para abrir uno de los archivos  cada conjunto de datos.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import xarray as xr

# %%
ozono = xr.open_dataset("/content/drive/My Drive/AnalisisEspacial/Clases/o3.nc")

# %%
ozono
# Out:
# <xarray.Dataset>
# Dimensions:                                        (latitude_centers: 18,
#                                                     longitude_centers: 18,
#                                                     altitude: 41, instruments: 6)
# Coordinates:
#   * latitude_centers                               (latitude_centers) float32 ...
#   * longitude_centers                              (longitude_centers) float32 ...
#   * altitude                                       (altitude) float32 10.0 .....
#   * instruments                                    (instruments) int16 1 2 ... 6
# Data variables:
#     merged_ozone_concentration                     (longitude_centers, latitude_centers, altitude) float64 ...
#     uncertainty_of_merged_ozone_concentration      (longitude_centers, latitude_centers, altitude) float64 ...
#     ozone_concentration_instrument                 (instruments, longitude_centers, latitude_centers, altitude) float64 ...
# ...

# %%
co2 = xr.open_dataset("/content/drive/My Drive/AnalisisEspacial/Clases/co2.nc")

# %%
co2
# Out:
# <xarray.Dataset>
# Dimensions:                  (sounding_dim: 437, layer_dim: 10, level_dim: 11)
# Dimensions without coordinates: sounding_dim, layer_dim, level_dim
# Data variables: (12/18)
#     longitude                (sounding_dim) float32 ...
#     latitude                 (sounding_dim) float32 ...
#     time                     (sounding_dim) datetime64[ns] ...
#     solar_zenith_angle       (sounding_dim) float32 ...
#     sensor_zenith_angle      (sounding_dim) float32 ...
#     xco2_quality_flag        (sounding_dim) int8 ...
#     ...                       ...
#     median_processor_id      (sounding_dim) int16 ...
#     median_uncertainty       (sounding_dim) float32 ...
#     median_uncertainty_se    (sounding_dim) float32 ...
#     median_uncertainty_ex    (sounding_dim) float32 ...
#     xco2_accuracy            (sounding_dim) float32 ...
#     contributing_algorithms  (sounding_dim) int8 ...
# Attributes: (12/37)
#     title:                     EMMA
# ...

# %%
turismo = xr.open_dataset("/content/drive/My Drive/AnalisisEspacial/Clases/turismo.nc")

# %%
turismo
# Out:
# <xarray.Dataset>
# Dimensions:       (rlat: 412, rlon: 424, time: 365, bnds: 2)
# Coordinates:
#   * rlat          (rlat) float64 -23.38 -23.27 -23.16 ... 21.62 21.73 21.84
#   * rlon          (rlon) float64 -28.38 -28.27 -28.16 ... 17.94 18.05 18.16
#   * time          (time) datetime64[ns] 1970-01-01T12:00:00 ... 1970-12-31T12...
#     lon           (rlat, rlon) float64 ...
#     lat           (rlat, rlon) float64 ...
# Dimensions without coordinates: bnds
# Data variables:
#     time_bounds   (time, bnds) datetime64[ns] ...
#     cit-proj      (time, rlat, rlon) float64 ...
#     rotated_pole  |S1 ...
# Attributes: (12/14)
#     Conventions:    CF-1.7
#     title:          Climate Index for Tourism (CIT) daily data for C3S Europe...
#     references:     de Freitas et al. 2008, https://doi.org/10.1007/s00484-00...
#     source:         Processing of ECVs from EURO-CORDEX climate projections
#     institution:    CMCC, Centro Euro-Mediterraneo sui Cambiamenti Climatici,...
# ...

# %%
mosquitos = xr.open_dataset("/content/drive/My Drive/AnalisisEspacial/Clases/mosquito.nc")

# %%
mosquitos
# Out:
# <xarray.Dataset>
# Dimensions:      (time: 100, lat: 425, lon: 599)
# Coordinates:
#     height       float64 ...
#   * lat          (lat) float64 30.1 30.2 30.3 30.4 30.5 ... 72.2 72.3 72.4 72.5
#   * lon          (lon) float64 -24.9 -24.8 -24.7 -24.6 ... 34.6 34.7 34.8 34.9
#   * time         (time) datetime64[ns] 1986-01-01 1987-01-01 ... 2085-01-01
# Data variables:
#     suitability  (time, lat, lon) float32 ...
# Attributes:
#     title:          Processed EURO-CORDEX future climate data for the health ...
#     conventions:    CF-1.6
#     project:        Copernicus Climate Change Service Sectoral Information Sy...
#     source:         Processing of bias-corrected EURO-CORDEX data by VITO
#     contact:        bd_rma@vito.be
#     creation_date:  Wed May 15 14:22:48 2019
#     institution:    VITO (https://vito.be/en)

# %%
erosion = xr.open_dataset("/content/drive/My Drive/AnalisisEspacial/Clases/erosion.nc")

# %%
erosion
# Out:
# <xarray.Dataset>
# Dimensions:    (time: 1, bnds: 2, lon: 49, lat: 43)
# Coordinates:
#   * time       (time) datetime64[ns] 1995-06-15
#   * lon        (lon) float32 6.5 6.75 7.0 7.25 7.5 ... 17.75 18.0 18.25 18.5
#   * lat        (lat) float32 47.0 46.75 46.5 46.25 ... 37.25 37.0 36.75 36.5
# Dimensions without coordinates: bnds
# Data variables:
#     time_bnds  (time, bnds) datetime64[ns] ...
#     rf         (time, lat, lon) float32 ...
# Attributes:
#     Conventions:  CF-1.6
#     contacts:     copernicus-support@ecmwf.int
#     contract:     C3S Demo Case Soil Erosion
#     title:        Soil erosion indicators for Italy from 1981 to 2080
#     institution:  Fondazione Centro Euro-Mediterraneo sui Cambiamenti Climati...
#     author:       Dr. Monia Santini; monia.santini@cmcc.it
#     version:      version 1.0

# %%
maiz = xr.open_dataset("/content/drive/My Drive/AnalisisEspacial/Clases/maiz.nc")

# %%
maiz
# Out:
# <xarray.Dataset>
# Dimensions:  (lat: 1800, lon: 3600, time: 1)
# Coordinates:
#   * lat      (lat) float32 -90.0 -89.9 -89.8 -89.7 -89.6 ... 89.6 89.7 89.8 89.9
#   * lon      (lon) float32 -180.0 -179.9 -179.8 -179.7 ... 179.7 179.8 179.9
#   * time     (time) datetime64[ns] 2017-01-10
# Data variables:
#     DVS      (time, lat, lon) float32 ...
# Attributes:
#     title:                Results for Maize from CSSF model for C3S_422 Globa...
#     institution:          Copernicus Climate Change Service (https://climate....
#     source:               Wageningen Environmental Research
#     comment:              EO-based crop productivity indicators from C3S CRUC...
#     conventions:          CF-1.6
#     contact:              Allard de Wit (allard.dewit@wur.nl)
#     project:              C3S_422 Global_Agriculture
#     creation_date:        2021-06-04 13:21:00.604391
#     keywords:             Maize, yield, total biomass, phenology
#     Unlimited_Dimension:  time

# %%
calor = xr.open_dataset("/content/drive/My Drive/AnalisisEspacial/Clases/calor.nc")

# %%
calor
# Out:
# <xarray.Dataset>
# Dimensions:        (lat: 425, lon: 599, time: 100)
# Coordinates:
#     height         float64 ...
#   * lat            (lat) float64 30.1 30.2 30.3 30.4 ... 72.2 72.3 72.4 72.5
#   * lon            (lon) float64 -24.9 -24.8 -24.7 -24.6 ... 34.6 34.7 34.8 34.9
#   * time           (time) datetime64[ns] 1986-01-01 1987-01-01 ... 2085-01-01
# Data variables:
#     HWD_EU_health  (time, lat, lon) float32 ...
# Attributes:
#     title:          Processed EURO-CORDEX future climate data for the health ...
#     conventions:    CF-1.6
#     project:        Copernicus Climate Change Service Sectoral Information Sy...
#     source:         Processing of bias-corrected EURO-CORDEX data by VITO
#     contact:        bd_rma@vito.be
#     creation_date:  Mon Jun 24 13:32:30 2019
#     institution:    VITO (https://vito.be/en)

# %%
radiacion = xr.open_dataset("/content/drive/My Drive/AnalisisEspacial/Clases/radiacion.nc")

# %%
radiacion
# Out:
# <xarray.Dataset>
# Dimensions:      (lat: 360, lon: 720)
# Coordinates:
#   * lat          (lat) float32 -89.75 -89.25 -88.75 -88.25 ... 88.75 89.25 89.75
#   * lon          (lon) float32 -179.8 -179.2 -178.8 -178.2 ... 178.8 179.2 179.8
# Data variables: (12/16)
#     pixel_count  (lat, lon) float64 ...
#     cloud_count  (lat, lon) float64 ...
#     sis          (lat, lon) float32 ...
#     sis_std      (lat, lon) float32 ...
#     srs          (lat, lon) float32 ...
#     srs_std      (lat, lon) float32 ...
#     ...           ...
#     sdl          (lat, lon) float32 ...
#     sdl_std      (lat, lon) float32 ...
#     snl          (lat, lon) float32 ...
#     snl_std      (lat, lon) float32 ...
#     srb          (lat, lon) float32 ...
#     srb_std      (lat, lon) float32 ...
# Attributes: (12/37)
#     Conventions:               CF-1.6
#     tracking_id:               de5d7be2-5391-465e-89df-fdfb2f583d8e
#     naming_authority:          uk.ac.stfc
# ...

# %%
quema = xr.open_dataset("/content/drive/My Drive/AnalisisEspacial/Clases/quema.nc")

# %%
quema
# Out:
# <xarray.Dataset>
# Dimensions:      (time: 1, lat: 33842, lon: 31616, bounds: 2)
# Coordinates:
#   * lon          (lon) float64 -105.0 -105.0 -105.0 ... -34.01 -34.0 -34.0
#   * lat          (lat) float64 19.0 19.0 19.0 18.99 ... -56.99 -57.0 -57.0
#   * time         (time) datetime64[ns] 2019-01-01
# Dimensions without coordinates: bounds
# Data variables:
#     JD           (time, lat, lon) int16 ...
#     CL           (time, lat, lon) int8 ...
#     LC           (time, lat, lon) uint8 ...
#     lat_bounds   (lat, bounds) float64 ...
#     lon_bounds   (lon, bounds) float64 ...
#     time_bounds  (time, bounds) datetime64[ns] ...
# Attributes: (12/38)
#     title:                      Fire_cci Pixel MODIS Burned Area product
#     institution:                University of Alcala
#     source:                     MODIS MOD09GQ Collection 6, MODIS MOD09GA Col...
#     history:                    Created on 2017-12-19 06:42:41; modified with...
# ...
